# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_error_web_sm
# !python -m spacy download en_error_web_lg
# Out:
# Requirement already satisfied: pip in c:\anaconda\lib\site-packages (22.3.1)
# Collecting pip
#   Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (65.6.3)
# Collecting setuptools
#   Using cached setuptools-69.1.0-py3-none-any.whl (819 kB)
# Requirement already satisfied: wheel in c:\anaconda\lib\site-packages (0.38.4)
# Collecting wheel
#   Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# ERROR: To modify pip, please run the following command:
# C:\Anaconda\python.exe -m pip install -U pip setuptools wheel
# Requirement already satisfied: spacy in c:\anaconda\lib\site-packages (3.7.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\anaconda\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: numpy>=1.19.0 in c:\anaconda\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\anaconda\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\anaconda\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from spacy) (22.0)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\anaconda\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\anaconda\lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\anaconda\lib\site-packages (from spacy) (1.10.11)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\anaconda\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\anaconda\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\anaconda\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\anaconda\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\anaconda\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\anaconda\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\anaconda\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\anaconda\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\anaconda\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\anaconda\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: jinja2 in c:\anaconda\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\anaconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\anaconda\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\anaconda\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.9)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\anaconda\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\anaconda\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\lib\site-packages (from jinja2->spacy) (2.1.1)
#
# [x] No compatible package found for 'en_error_web_sm' (spaCy
# v3.7.4)
#
#
# [x] No compatible package found for 'en_error_web_lg' (spaCy
# v3.7.4)

# %%
# !pip install lxml
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: lxml in c:\anaconda\lib\site-packages (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\lib\site-packages (from beautifulsoup4) (2.3.2.post1)

# %%
import spacy

#NER--> Name Entity Recognition

# %%
text = ''' Dhaka is the capital city of Bangladesh, in southern Asia. Set beside the Buriganga River, it’s at the center of national government, trade and culture. The 17th-century old city was the Mughal capital of Bengal, and many palaces and mosques remain. American architect Louis Khan’s National Parliament House complex typifies the huge, fast-growing modern metropolis.
'''

# %%
print(text)
# Out:
#  Dhaka is the capital city of Bangladesh, in southern Asia. Set beside the Buriganga River, it’s at the center of national government, trade and culture. The 17th-century old city was the Mughal capital of Bengal, and many palaces and mosques remain. American architect Louis Khan’s National Parliament House complex typifies the huge, fast-growing modern metropolis.

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Dhaka ORG
# Bangladesh GPE
# Asia LOC
# the Buriganga River LOC
# 17th-century DATE
# Mughal PERSON
# Bengal GPE
# mosques FAC
# American NORP
# Louis Khan’s PERSON
# National Parliament House ORG

# %%
spacy.explain("ORG")
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
from bs4 import BeautifulSoup
import requests
from spacy import displacy

# %%
url = "https://www.bbc.com/news/business-61589229"

# %%
html_content = requests.get(url).text

# %%
html_content
# Out:
# '<!DOCTYPE html><html lang="en-GB" class="no-js"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title data-rh="true">Twitter investor sues Elon Musk and platform over takeover bid - BBC News</title><meta data-rh="true" name="description" content="The lawsuit alleges the multi-billionaire&#x27;s &quot;wrongful conduct&quot; has caused Twitter shares to plunge."/><meta data-rh="true" name="theme-color" content="#FFFFFF"/><meta data-rh="true" property="article:author" content="https://www.facebook.com/bbcnews"/><meta data-rh="true" property="fb:admins" content="100004154058350"/><meta data-rh="true" property="fb:app_id" content="1609039196070050"/><meta data-rh="true" property="og:description" content="The lawsuit alleges the multi-billionaire&#x27;s &quot;wrongful conduct&quot; has caused Twitter shares to plunge."/><meta data-rh="true" property="og:image" content="https://ichef.bbci.co.uk/news/1024/branded_news/17361/production/_124937059_gettyimages-1240408699.jpg"/><meta data-rh="true" property="og:image:alt" content="Elon Musk at the 2022 Met Gala."/><meta data-rh="true" property="og:locale" content="en_GB"/><meta data-rh="true" property="og:site_name" content="BBC News"/><meta data-rh="true" property="og:title" content="Twitter investor sues Elon Musk and platform over takeover bid"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="og:url" content="https://www.bbc.com/news/business-61589229"/><meta data-rh="true" property="article:section" content="Business"/><meta data-rh="true" name="twitter:card" content="summary_large_image"/><meta data-rh="true" name="twitter:creator" content="@BBCWorld"/><meta data-rh="true" name="twitter:description" content="The lawsuit alleges the multi-billionaire&#x27;s &quot;wrongful conduct&quot; has caused Twitter shares to plunge."/><meta data-rh="true" name="twitter:image:src" content="https://ichef.bbci.co.uk/news/1024/branded_news/17361/production/_124937059_gettyimages-1240408699.jpg"/><meta data-rh="true" name="twitter:image:alt" content="Elon Musk at the 2022 Met Gala."/><meta data-rh="true" name="twitter:site" content="@BBCWorld"/><meta data-rh="true" name="twitter:title" content="Twitter investor sues Elon Musk and platform over takeover bid"/><meta data-rh="true" type="metaTags" name="mobile-web-app-capable" content="yes"/><meta data-rh="true" type="metaTags" name="msapplication-TileColor" content="#bb1919"/><meta data-rh="true" type="metaTags" name="msapplication-TileImage" content="https://static.files.bbci.co.uk/core/website/assets/static/icons/windows-phone/news/windows-phone-icon-270x270.23502b4459eb7a6ab2ab.png"/><meta data-rh="true" name="format-detection" content="telephone=no"/><link data-rh="true" rel="canonical" href="https://www.bbc.com/news/business-61589229"/><link data-rh="true" rel="amphtml" href="https://www.bbc.com/news/business-61589229.amp"/><link data-rh="true" rel="alternate" hrefLang="x-default" href="https://www.bbc.com/news/business-61589229"/><link data-rh="true" rel="alternate" hrefLang="en-gb" href="https://www.bbc.co.uk/news/business-61589229"/><link data-rh="true" rel="alternate" hrefLang="en" href="https://www.bbc.com/news/business-61589229"/><link data-rh="true" rel="manifest" href="https://static.files.bbci.co.uk/core/manifest.8d4237cbd18eb052a5fa59995d4624b88fd4c643.json"/><script data-rh="true" type="application/ld+json">{"@context":"http://schema.org","@type":"ReportageNewsArticle","url":"https://www.bbc.com/news/business-61589229","publisher":{"@type":"NewsMediaOrganization","name":"BBC News","publishingPrinciples":"http://www.bbc.co.uk/news/help-41670342","logo":{"@type":"ImageObject","url":"https://static.files.bbci.co.uk/ws/simorgh-assets/public/news/images/metadata/poster-1024x576.png"}},"datePublished":"2022-05-27T04:45:11.000Z","dateModified":"2022-05-27T07:47:43.000Z","description":"The lawsuit alleges the multi-billionaire\'s \\"wrongful conduct\ ...

# %%
soup = BeautifulSoup(html_content,'lxml')

# %%
body = soup.body.text

# %%
body
# Out:
# Twitter PRODUCT
# more than 95 CARDINAL
# Musk PERSON
# 13 May DATE
# Twitter PRODUCT
# Twitter PERSON
# Javascript PERSON
# TwitterThe BBC ORG
# Elon MuskAllow Twitter PERSON
# Twitter PERSON
# Twitterâs ORG
# BBC ORG
# Elon MuskIt PERSON
# four days later DATE
# Twitter PRODUCT
# Friday DATE
# Frank Bottini PERSON
# Twitter NORP
# BBC ORG
# 44bn MONEY
# San Francisco GPE
# Musk PERSON
# " Mr Bottini WORK_OF_ART
# Musk PERSON
# Tesla ORG
# BBC ORG
# Friday DATE
# Twitter PERSON
# BBC.Analysts ORG
# Musk PERSON
# Twitter PRODUCT
# Musk PERSON
# Twitter PERSON
# 44bn MONEY
# March DATE
# earlier this month DATE
# the question" DATE
# Earlier this month DATE
# Florida GPE
# Musk PERSON
# months DATE
# The Orlando Police Pension Fund ORG
# Musk PERSON
# Twitter PRODUCT
# Jack Dorsey PERSON
# US GPE
# Delaware GPE
# Twitter PERSON
# 2025.The CARDINAL
# Twitter PRODUCT
# JavaScript PRODUCT
# Elon Musk PERSON
# Tesla ORG
# TopicsSocial ORG
# Musk PERSON
# May 2022Musk DATE
# Twitter PRODUCT
# May 2022Twitter DATE
# Musk PERSON
# 2022Elon CARDINAL
# 44bn MONEY
# May 2022Twitter DATE
# Musk PERSON
# May 2022Top DATE
# StoriesChina ORG
# US GPE
# hours TIME
# agoPakistan GPE
# powerPublished9 hours TIME
# agoIndia GPE
# Brazil GPE
# him?'The ORG
# Universe PERSON
# Russia GPE
# Wagner ORG
# AfricaNavalny ORG
# Israelis NORP
# Sydney scramblingRussia PERSON
# AvdiivkaElsewhere GPE
# Gen Z WORK_OF_ART
# Read1China PERSON
# US GPE
# second ORDINAL
# YouTuber Ruby Franke ORG
# days DATE
# power6Indian NORP
# more than 100 CARDINAL
# 11-year-old DATE
# Texas GPE
# Bezos PERSON
# 8.5bn MONEY
# BBC ORG
# UseAbout ORG
# NewslettersWhy ORG
# BBCAdvertise ORG
# 2024 DATE
# BBC ORG
# BBC ORG

# %%
displacy.render(doc,style = 'ent',jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  HomepageSkip to contentAccessibility
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HelpYour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  accountHomeNewsSportEarthReelWorklifeTravelMore menuMore menuSearch BBCHomeNewsSportEarthReelWorklifeTravelCultureFutureMusicTVWeatherSoundsClose menuBBC
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NewsMenuHomeIsrael-Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     warWar in UkraineClimateVideoWorldAsiaUKBusinessTechMoreScienceEntertainment &amp; ArtsHealthWorld News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  TVIn PicturesBBC VerifyNewsbeatBusinessMarket
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataNew Tech EconomyTechnology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of BusinessCEO SecretsArtificial IntelligencePaths to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SuccessTwitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  investor sues
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and platform over takeover bidPublished27
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 2022Shareclose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  panelShare pageCopy linkAbout sharingImage source,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty ImagesBy Annabelle  LiangBusiness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reporterA Twitter investor is suing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the social media platform over the handling of the billionaire's $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     44bn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (Â£34.9bn) bid for the company. The case alleges he violated
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  corporate laws in a number of ways.It accuses the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  boss of &quot;wrongful conduct&quot; as his &quot;false statements and market manipulation have created 'chaos' at
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's headquarters in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco&quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .Twitter shares are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around 27%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  lower than Mr Musk's $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     54.20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  offer price.The proposed class action lawsuit was filed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the US District Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Northern District
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  by investor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William Heresniak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who said he was acting &quot;on behalf of himself and all others similarly situated&quot;.A class-action is a lawsuit that h
